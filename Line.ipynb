# %%
import pandas as pd

# %%
excel = pd.ExcelFile('aus.xlsx')
data = pd.read_excel(excel, 'Table 2.1',skiprows =16)
data
# Out:
#                            Direction                       Visa groupings(d)  \
# 0       Overseas migrant arrivals(e)                         Permanent visas
# 1                                NaN                                     NaN
# 2                                NaN                                     NaN
# 3                                NaN                                     NaN
# 4                                NaN                   Total permanent visas
# 5                                NaN                         Temporary visas
# 6                                NaN                                     NaN
# 7                                NaN                                     NaN
# 8                                NaN                                     NaN
# 9                                NaN                                     NaN
# 10                               NaN                                     NaN
# ...

# %%
data1 = data.iloc[0:15]

# %%
data1
# Out:
#                        Direction                       Visa groupings(d)  \
# 0   Overseas migrant arrivals(e)                         Permanent visas
# 1                            NaN                                     NaN
# 2                            NaN                                     NaN
# 3                            NaN                                     NaN
# 4                            NaN                   Total permanent visas
# 5                            NaN                         Temporary visas
# 6                            NaN                                     NaN
# 7                            NaN                                     NaN
# 8                            NaN                                     NaN
# 9                            NaN                                     NaN
# 10                           NaN                                     NaN
# 11                           NaN                                     NaN
# ...

# %%
data1.at[13,"Unnamed: 2"]= "New Zealand citizen"
data1.at[14,"Unnamed: 2"]= "Australian citizens "

# %%
data1=data1.drop(columns=["Visa groupings(d)","Direction"])

# %%
data1.rename(columns={"Unnamed: 2":'type'}, inplace = True)

# %%
data1.dropna(inplace=True)

# %%
data1.reset_index(drop=True,inplace=True)

# %%
data1
# Out:
#                                            type  2004-05  2005-06  2006-07  \
# 0                                        Family  28430.0  30400.0  32480.0
# 1                           Skilled (permanent)  35540.0  42750.0  47540.0
# 2            Special eligibility & humanitarian  13580.0  12320.0  12400.0
# 3                             Other (permanent)   3650.0   3640.0   3770.0
# 4   Student - vocational education and training   7990.0  10500.0  19970.0
# 5                    Student - higher education  32750.0  42040.0  57940.0
# 6                               Student - other  25440.0  20550.0  25810.0
# 7                           Skilled (temporary)  17100.0  27730.0  35850.0
# 8                               Working holiday  12930.0  17080.0  21630.0
# 9                                      Visitors  35770.0  36100.0  37590.0
# 10                            Other (temporary)   9320.0   7580.0   6780.0
# ...

# %%
temp = 2004
for i in range(1,len(data1.columns)):
    data1.rename(columns={data1.columns[i]:f'{temp}'}, inplace = True)
    temp +=1

# %%
data1
# Out:
#                                            type     2004     2005     2006  \
# 0                                        Family  28430.0  30400.0  32480.0
# 1                           Skilled (permanent)  35540.0  42750.0  47540.0
# 2            Special eligibility & humanitarian  13580.0  12320.0  12400.0
# 3                             Other (permanent)   3650.0   3640.0   3770.0
# 4   Student - vocational education and training   7990.0  10500.0  19970.0
# 5                    Student - higher education  32750.0  42040.0  57940.0
# 6                               Student - other  25440.0  20550.0  25810.0
# 7                           Skilled (temporary)  17100.0  27730.0  35850.0
# 8                               Working holiday  12930.0  17080.0  21630.0
# 9                                      Visitors  35770.0  36100.0  37590.0
# 10                            Other (temporary)   9320.0   7580.0   6780.0
# ...

# %%
data1.to_csv("visa.csv")

# %%
temp =0 
for i in range(2,10):
    test = pd.read_excel(excel, f'Table 2.{i}',skiprows =15).drop(columns=["Direction","Visa groupings(c)"]).loc[15].rename(f"{temp}").to_frame().T
    temp1 = 2004
    temp2 = 0
    for i in test.columns:
        test.rename(columns={i:f'{temp1}'}, inplace = True)
        arrive.loc[lst[temp],f'{temp1}'] = test.iloc[0,temp2]
        temp1 +=1
        temp2 +=1
   
    
    temp += 1
arrive

# %%
lst = ["New South Wales","Victoria","Queensland","South Australia","Western Australia","Tasmania","Northern Territory","Australian Capital Territory"]

# %%
for i in range(2,10):
    test = pd.read_excel(excel, f'Table 2.{i}',skiprows =15).drop(columns=["Direction","Visa groupings(c)"])
    test = test.iloc[0:12]
    test.rename(columns={"Unnamed: 2":'type'}, inplace = True)
    test.dropna(inplace=True)
    test.reset_index(drop=True,inplace=True)
    temp = 2004
    for x in test.columns:
        if x =="type":
            continue
        test.rename(columns={x:f'{temp}'}, inplace = True)
        temp +=1
    test.to_csv(f"visa/{lst[i-2]}.csv")

# %%
test
# Out:
#                                            2004     2005     2006     2007  \
# 0                                        Family  12370.0  13250.0  13530.0
# 1                           Skilled (permanent)  11690.0  12410.0  12890.0
# 2            Special eligibility & humanitarian   4420.0   4410.0   4200.0
# 3                             Other (permanent)   1350.0   1360.0   1370.0
# 4   Student - vocational education and training   3790.0   4870.0   9390.0
# 5                    Student - higher education  11440.0  14830.0  20110.0
# 6                               Student - other   9620.0   7410.0   9980.0
# 7                           Skilled (temporary)   6330.0   7820.0   9590.0
# 8                               Working holiday   7060.0   9020.0  10700.0
# 9                                      Visitors  15530.0  14910.0  15530.0
# 10                            Other (temporary)   3070.0   2540.0   2390.0
#
# ...
